# %%
import pandas as pd

car_data_df = pd.read_csv('./archive/CarPrice_Assignment.csv', engine='pyarrow', dtype_backend='pyarrow')

car_data_df =car_data_df.dropna()

# prepare feature set
feature_set = car_data_df
feature_set['CarName'] = feature_set['CarName'].astype("string").str.split(" ").str.get(0)
feature_columns = ['CarName', 'fueltype', 'aspiration', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'horsepower', 'citympg', 'highwaympg']
input_data = feature_set[feature_columns]
# one hot encoding feature set

input_data = pd.get_dummies(input_data, columns=['CarName'], drop_first=False)
input_data = pd.get_dummies(input_data, columns=['fueltype'], drop_first=False)
input_data = pd.get_dummies(input_data, columns=['aspiration'], drop_first=False)
input_data = pd.get_dummies(input_data, columns=['carbody'], drop_first=False)
input_data = pd.get_dummies(input_data, columns=['drivewheel'], drop_first=False)
input_data = pd.get_dummies(input_data, columns=['enginelocation'], drop_first=False)
input_data = pd.get_dummies(input_data, columns=['enginetype'], drop_first=False)
input_data = pd.get_dummies(input_data, columns=['cylindernumber'], drop_first=False)

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 64 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   wheelbase              205 non-null    double[pyarrow]
#  1   carlength              205 non-null    double[pyarrow]
#  2   carwidth               205 non-null    double[pyarrow]
#  3   curbweight             205 non-null    int64[pyarrow]
#  4   enginesize             205 non-null    int64[pyarrow]
#  5   horsepower             205 non-null    int64[pyarrow]
#  6   citympg                205 non-null    int64[pyarrow]
#  7   highwaympg             205 non-null    int64[pyarrow]
#  8   CarName_Nissan         205 non-null    bool
#  9   CarName_alfa-romero    205 non-null    bool
#  10  CarName_audi           205 non-null    bool
#  11  CarName_bmw            205 non-null    bool
#  12  CarName_buick          205 non-null    bool
# ...

# %%
feature_set['CarName']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
# 5             audi
# 6             audi
# 7             audi
# 8             audi
# 9             audi
# 10             bmw
# 11             bmw
# 12             bmw
# 13             bmw
# 14             bmw
# 15             bmw
# 16             bmw
# 17             bmw
# 18       chevrolet
# 19       chevrolet
# 20       chevrolet
# 21           dodge
# 22           dodge
# 23           dodge
# 24           dodge
# 25           dodge
# 26           dodge
# 27           dodge
# 28           dodge
# 29           dodge
# 30           honda
# 31           honda
# 32           honda
# 33           honda
# 34           honda
# 35           honda
# 36           honda
# 37           honda
# 38           honda
# 39           honda
# 40           honda
# 41           honda
# 42           honda
# 43           isuzu
# 44           isuzu
# 45           isuzu
# 46           isuzu
# ...
